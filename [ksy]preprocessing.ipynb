# %% [markdown]
# <a href="https://colab.research.google.com/github/ferrry-ghsb/bigdata_6team/blob/main/%5Bksy%5Dpreprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import io
import pandas as pd

# %%
hol = pd.read_csv('/content/drive/MyDrive/store-sales-time-series-forecasting/holidays_events.csv')
oil = pd.read_csv('/content/drive/MyDrive/store-sales-time-series-forecasting/oil.csv')
submission = pd.read_csv('/content/drive/MyDrive/store-sales-time-series-forecasting/sample_submission.csv')
stores = pd.read_csv('/content/drive/MyDrive/store-sales-time-series-forecasting/stores.csv')
test = pd.read_csv('/content/drive/MyDrive/store-sales-time-series-forecasting/test.csv')
train = pd.read_csv('/content/drive/MyDrive/store-sales-time-series-forecasting/train.csv')
transaction = pd.read_csv('/content/drive/MyDrive/store-sales-time-series-forecasting/transactions.csv')

# %%
#2012-03-02 ~ 2017-12-26까지의 데이터
hol.head()
# Out:
#          date     type  ...                    description transferred
# 0  2012-03-02  Holiday  ...             Fundacion de Manta       False
# 1  2012-04-01  Holiday  ...  Provincializacion de Cotopaxi       False
# 2  2012-04-12  Holiday  ...            Fundacion de Cuenca       False
# 3  2012-04-14  Holiday  ...      Cantonizacion de Libertad       False
# 4  2012-04-21  Holiday  ...      Cantonizacion de Riobamba       False
#
# [5 rows x 6 columns]

# %%
hol.tail()
# Out:
#            date        type    locale locale_name description  transferred
# 345  2017-12-22  Additional  National     Ecuador   Navidad-3        False
# 346  2017-12-23  Additional  National     Ecuador   Navidad-2        False
# 347  2017-12-24  Additional  National     Ecuador   Navidad-1        False
# 348  2017-12-25     Holiday  National     Ecuador     Navidad        False
# 349  2017-12-26  Additional  National     Ecuador   Navidad+1        False

# %%
hol.describe()
# Out:
#               date     type    locale locale_name description transferred
# count          350      350       350         350         350         350
# unique         312        6         3          24         103           2
# top     2014-06-25  Holiday  National     Ecuador    Carnaval       False
# freq             4      221       174         174          10         338

# %%
oil.describe()
# Out:
#         dcoilwtico
# count  1175.000000
# mean     67.714366
# std      25.630476
# min      26.190000
# 25%      46.405000
# 50%      53.190000
# 75%      95.660000
# max     110.620000

# %%
oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
oil.tail()
# Out:
#             date  dcoilwtico
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26

# %%
submission.describe()
# Out:
#                  id    sales
# count  2.851200e+04  28512.0
# mean   3.015144e+06      0.0
# std    8.230850e+03      0.0
# min    3.000888e+06      0.0
# 25%    3.008016e+06      0.0
# 50%    3.015144e+06      0.0
# 75%    3.022271e+06      0.0
# max    3.029399e+06      0.0

# %%
#54개 store, 17개 클러스터
stores.describe()
# Out:
#        store_nbr    cluster
# count  54.000000  54.000000
# mean   27.500000   8.481481
# std    15.732133   4.693395
# min     1.000000   1.000000
# 25%    14.250000   4.000000
# 50%    27.500000   8.500000
# 75%    40.750000  13.000000
# max    54.000000  17.000000

# %%
stores
# Out:
#     store_nbr           city                           state type  cluster
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# ...

# %%
#2017-08-16 ~ 2017-08-31
test.head()
# Out:
#         id        date  store_nbr      family  onpromotion
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0
# 1  3000889  2017-08-16          1   BABY CARE            0
# 2  3000890  2017-08-16          1      BEAUTY            2
# 3  3000891  2017-08-16          1   BEVERAGES           20
# 4  3000892  2017-08-16          1       BOOKS            0

# %%
test.tail()
# Out:
#             id        date  store_nbr                      family  onpromotion
# 28507  3029395  2017-08-31          9                     POULTRY            1
# 28508  3029396  2017-08-31          9              PREPARED FOODS            0
# 28509  3029397  2017-08-31          9                     PRODUCE            1
# 28510  3029398  2017-08-31          9  SCHOOL AND OFFICE SUPPLIES            9
# 28511  3029399  2017-08-31          9                     SEAFOOD            0

# %%
test.describe()
# Out:
#                  id     store_nbr   onpromotion
# count  2.851200e+04  28512.000000  28512.000000
# mean   3.015144e+06     27.500000      6.965383
# std    8.230850e+03     15.586057     20.683952
# min    3.000888e+06      1.000000      0.000000
# 25%    3.008016e+06     14.000000      0.000000
# 50%    3.015144e+06     27.500000      0.000000
# 75%    3.022271e+06     41.000000      6.000000
# max    3.029399e+06     54.000000    646.000000

# %%
#2013-01-01 ~ 2017-08-15까지의 데이터
train.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
train.tail()
# Out:
#               id        date  ...     sales onpromotion
# 3000883  3000883  2017-08-15  ...   438.133           0
# 3000884  3000884  2017-08-15  ...   154.553           1
# 3000885  3000885  2017-08-15  ...  2419.729         148
# 3000886  3000886  2017-08-15  ...   121.000           8
# 3000887  3000887  2017-08-15  ...    16.000           0
#
# [5 rows x 6 columns]

# %%
train.describe()
# Out:
#                  id     store_nbr         sales   onpromotion
# count  3.000888e+06  3.000888e+06  3.000888e+06  3.000888e+06
# mean   1.500444e+06  2.750000e+01  3.577757e+02  2.602770e+00
# std    8.662819e+05  1.558579e+01  1.101998e+03  1.221888e+01
# min    0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    7.502218e+05  1.400000e+01  0.000000e+00  0.000000e+00
# 50%    1.500444e+06  2.750000e+01  1.100000e+01  0.000000e+00
# 75%    2.250665e+06  4.100000e+01  1.958473e+02  0.000000e+00
# max    3.000887e+06  5.400000e+01  1.247170e+05  7.410000e+02

# %%
transaction.describe()
# Out:
#           store_nbr  transactions
# count  83488.000000  83488.000000
# mean      26.939237   1694.602158
# std       15.608204    963.286644
# min        1.000000      5.000000
# 25%       13.000000   1046.000000
# 50%       27.000000   1393.000000
# 75%       40.000000   2079.000000
# max       54.000000   8359.000000

# %%
hol["date"][41]
# Out:
# '2013-01-01'

# %%
hol["date"][327]
# Out:
# '2017-08-24'

# %%
hol["date"][328]
# Out:
# '2017-09-28'

# %%
#시간 구간을 2013-01-01부터 2017-08-31로 고정.
#hol이 시간 구간을 넘으므로 잘라서 사용.

# %%
hol = hol[41:328]

# %%
#train과 store을 store nber 기준으로 합병. 
#합병된 df이름은 train_cp
train_cp = train.merge(stores, how = 'left', left_on='store_nbr', right_on='store_nbr')

# %%
train_cp
# Out:
#               id        date  store_nbr  ...      state  type  cluster
# 0              0  2013-01-01          1  ...  Pichincha     D       13
# 1              1  2013-01-01          1  ...  Pichincha     D       13
# 2              2  2013-01-01          1  ...  Pichincha     D       13
# 3              3  2013-01-01          1  ...  Pichincha     D       13
# 4              4  2013-01-01          1  ...  Pichincha     D       13
# ...          ...         ...        ...  ...        ...   ...      ...
# 3000883  3000883  2017-08-15          9  ...  Pichincha     B        6
# 3000884  3000884  2017-08-15          9  ...  Pichincha     B        6
# 3000885  3000885  2017-08-15          9  ...  Pichincha     B        6
# 3000886  3000886  2017-08-15          9  ...  Pichincha     B        6
# 3000887  3000887  2017-08-15          9  ...  Pichincha     B        6
#
# [3000888 rows x 10 columns]

# %%
#train+store+oil
train_cp = train_cp.merge(oil, how = 'left', left_on='date', right_on='date')

# %%
train_cp
# Out:
#               id        date  store_nbr  ... type  cluster  dcoilwtico
# 0              0  2013-01-01          1  ...    D       13         NaN
# 1              1  2013-01-01          1  ...    D       13         NaN
# 2              2  2013-01-01          1  ...    D       13         NaN
# 3              3  2013-01-01          1  ...    D       13         NaN
# 4              4  2013-01-01          1  ...    D       13         NaN
# ...          ...         ...        ...  ...  ...      ...         ...
# 3000883  3000883  2017-08-15          9  ...    B        6       47.57
# 3000884  3000884  2017-08-15          9  ...    B        6       47.57
# 3000885  3000885  2017-08-15          9  ...    B        6       47.57
# 3000886  3000886  2017-08-15          9  ...    B        6       47.57
# 3000887  3000887  2017-08-15          9  ...    B        6       47.57
#
# [3000888 rows x 11 columns]

# %%
#train+store+oil+holiday
train_cp = train_cp.merge(hol, how = 'left', left_on='date', right_on='date')

# %%
train_cp
# Out:
#               id        date  ...            description transferred
# 0              0  2013-01-01  ...     Primer dia del ano       False
# 1              1  2013-01-01  ...     Primer dia del ano       False
# 2              2  2013-01-01  ...     Primer dia del ano       False
# 3              3  2013-01-01  ...     Primer dia del ano       False
# 4              4  2013-01-01  ...     Primer dia del ano       False
# ...          ...         ...  ...                    ...         ...
# 3054343  3000883  2017-08-15  ...  Fundacion de Riobamba       False
# 3054344  3000884  2017-08-15  ...  Fundacion de Riobamba       False
# 3054345  3000885  2017-08-15  ...  Fundacion de Riobamba       False
# 3054346  3000886  2017-08-15  ...  Fundacion de Riobamba       False
# 3054347  3000887  2017-08-15  ...  Fundacion de Riobamba       False
#
# [3054348 rows x 16 columns]

# %% [markdown]
# "store_nbr", "family", "city", "state", "type_x", "cluster", "type_y", "locale", "locale_name", "description",	"transferred" 는 원핫 인코딩 진행

# %%
#family unique값 확인
train_cp['family'].unique()
# Out:
# array(['AUTOMOTIVE', 'BABY CARE', 'BEAUTY', 'BEVERAGES', 'BOOKS',
#        'BREAD/BAKERY', 'CELEBRATION', 'CLEANING', 'DAIRY', 'DELI', 'EGGS',
#        'FROZEN FOODS', 'GROCERY I', 'GROCERY II', 'HARDWARE',
#        'HOME AND KITCHEN I', 'HOME AND KITCHEN II', 'HOME APPLIANCES',
#        'HOME CARE', 'LADIESWEAR', 'LAWN AND GARDEN', 'LINGERIE',
#        'LIQUOR,WINE,BEER', 'MAGAZINES', 'MEATS', 'PERSONAL CARE',
#        'PET SUPPLIES', 'PLAYERS AND ELECTRONICS', 'POULTRY',
#        'PREPARED FOODS', 'PRODUCE', 'SCHOOL AND OFFICE SUPPLIES',
#        'SEAFOOD'], dtype=object)

# %%
fam_name = ['AUTOMOTIVE', 'BABY CARE', 'BEAUTY', 'BEVERAGES', 'BOOKS',
       'BREAD/BAKERY', 'CELEBRATION', 'CLEANING', 'DAIRY', 'DELI', 'EGGS',
       'FROZEN FOODS', 'GROCERY I', 'GROCERY II', 'HARDWARE',
       'HOME AND KITCHEN I', 'HOME AND KITCHEN II', 'HOME APPLIANCES',
       'HOME CARE', 'LADIESWEAR', 'LAWN AND GARDEN', 'LINGERIE',
       'LIQUOR,WINE,BEER', 'MAGAZINES', 'MEATS', 'PERSONAL CARE',
       'PET SUPPLIES', 'PLAYERS AND ELECTRONICS', 'POULTRY',
       'PREPARED FOODS', 'PRODUCE', 'SCHOOL AND OFFICE SUPPLIES',
       'SEAFOOD']

# %%
#train_cp['family'].sum()

# %%
#plt.pie(ratio, labels=fam_name, autopct='%.1f%%')
#plt.show()

# %%
train_cp = train_cp[train_cp['store_nbr'] == 1]

# %%
train_cp.drop(['city', 'state', 'type_x', 'cluster'], axis = 1, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
train_cp.drop(['store_nbr', 'description', 'transferred'], axis = 1, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
train_cp['family'].unique()
# Out:
# array(['AUTOMOTIVE', 'BABY CARE', 'BEAUTY', 'BEVERAGES', 'BOOKS',
#        'BREAD/BAKERY', 'CELEBRATION', 'CLEANING', 'DAIRY', 'DELI', 'EGGS',
#        'FROZEN FOODS', 'GROCERY I', 'GROCERY II', 'HARDWARE',
#        'HOME AND KITCHEN I', 'HOME AND KITCHEN II', 'HOME APPLIANCES',
#        'HOME CARE', 'LADIESWEAR', 'LAWN AND GARDEN', 'LINGERIE',
#        'LIQUOR,WINE,BEER', 'MAGAZINES', 'MEATS', 'PERSONAL CARE',
#        'PET SUPPLIES', 'PLAYERS AND ELECTRONICS', 'POULTRY',
#        'PREPARED FOODS', 'PRODUCE', 'SCHOOL AND OFFICE SUPPLIES',
#        'SEAFOOD'], dtype=object)

# %%
train_cp.drop(['id', 'type_y', 'locale_name'], axis = 1, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
train_cp.drop(['locale'], axis = 1, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#1. family 별로 csv 따로 저장 후 학습 7일 치-> 1일 치 예측
#2. family 전부 다 들어있는 csv로 학습 7일 치*(family columns 개수) -> 1일 치*(family columns 개수) 예측 
#   family 사용할 columns ['GROCERY I', 'BEVERAGES', 'CLEANING', 'BREAD/BAKERY', 'DAIRY', 'POULTRY', 'MEATS', 'PERSONAL CARE', 'DELI']

# %%
fam = ['GROCERY I', 'BEVERAGES', 'CLEANING', 'BREAD/BAKERY', 'DAIRY', 'POULTRY', 'MEATS', 'PERSONAL CARE', 'DELI']

# %%
train_cp.set_index('date', drop=True, inplace=True)

# %%
train_cp
# Out:
#                                 family        sales  onpromotion  dcoilwtico
# date
# 2013-01-01                  AUTOMOTIVE     0.000000            0         NaN
# 2013-01-01                   BABY CARE     0.000000            0         NaN
# 2013-01-01                      BEAUTY     0.000000            0         NaN
# 2013-01-01                   BEVERAGES     0.000000            0         NaN
# 2013-01-01                       BOOKS     0.000000            0         NaN
# ...                                ...          ...          ...         ...
# 2017-08-15                     POULTRY   234.892000            0       47.57
# 2017-08-15              PREPARED FOODS    42.822998            0       47.57
# 2017-08-15                     PRODUCE  2240.230000            7       47.57
# 2017-08-15  SCHOOL AND OFFICE SUPPLIES     0.000000            0       47.57
# 2017-08-15                     SEAFOOD    22.487000            0       47.57
#
# [56562 rows x 4 columns]

# %%
train_bea = train_cp[train_cp['family'] == 'BEAUTY']
del train_bea['family']
train_bea['dcoilwtico'].fillna(method='bfill', inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
Train_bea = train_bea[:-200]
Test_bea = train_bea[-200:]
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
Train_bea = scaler.fit_transform(Train_bea)
Test_bea = scaler.transform(Test_bea)
Test_bea = pd.DataFrame(Test_bea)
Train_bea = pd.DataFrame(Train_bea)

# %%
Train_bea
# Out:
#              0    1         2
# 0     0.000000  0.0  0.792965
# 1     0.166667  0.0  0.792965
# 2     0.000000  0.0  0.790951
# 3     0.250000  0.0  0.792728
# 4     0.250000  0.0  0.793675
# ...        ...  ...       ...
# 1509  0.166667  0.5  0.319673
# 1510  0.166667  0.0  0.313159
# 1511  0.250000  0.5  0.313159
# 1512  0.583333  0.5  0.313159
# 1513  0.166667  0.5  0.314580
#
# [1514 rows x 3 columns]

# %%
Test_bea
# Out:
#             0    1         2
# 0    0.583333  0.5  0.328201
# 1    0.000000  0.0  0.324055
# 2    0.166667  0.5  0.327135
# 3    0.583333  0.5  0.317660
# 4    0.083333  0.0  0.317660
# ..        ...  ...       ...
# 195  0.083333  0.5  0.267914
# 196  0.250000  0.5  0.253464
# 197  0.083333  0.0  0.253464
# 198  0.500000  0.5  0.253464
# 199  0.333333  0.5  0.253228
#
# [200 rows x 3 columns]

# %%
#sales, promotion, fuel
Train_bea.to_csv("bea_train.csv")
Test_bea.to_csv("bea_test.csv")

# %%
for i in range(0, 8):
  train = train_cp[train_cp['family'] == fam[i]]
  train.to_csv("train" + str(i), header=True, index=True)

# %%
train0 = pd.read_csv('/content/train0')
train1 = pd.read_csv('/content/train1')
train2 = pd.read_csv('/content/train2')
train3 = pd.read_csv('/content/train3')
train4 = pd.read_csv('/content/train4')
train5 = pd.read_csv('/content/train5')
train6 = pd.read_csv('/content/train6')
train7 = pd.read_csv('/content/train7')

# %%
list = [train0, train1, train2, train3, train4, train5, train6, train7]

# %%
for i in list:
  i['dcoilwtico'].fillna(method='bfill', inplace = True)
  i.set_index('date', drop=True, inplace=True)

# %%
train0
# Out:
#                family   sales  onpromotion  dcoilwtico
# date
# 2013-01-01  GROCERY I     0.0            0       93.14
# 2013-01-02  GROCERY I  2652.0            0       93.14
# 2013-01-03  GROCERY I  2121.0            0       92.97
# 2013-01-04  GROCERY I  2056.0            0       93.12
# 2013-01-05  GROCERY I  2216.0            0       93.20
# ...               ...     ...          ...         ...
# 2017-08-11  GROCERY I  1270.0           24       48.81
# 2017-08-12  GROCERY I  1630.0           28       47.59
# 2017-08-13  GROCERY I   952.0           19       47.59
# 2017-08-14  GROCERY I  2407.0           30       47.59
# 2017-08-15  GROCERY I  2508.0           29       47.57
#
# [1714 rows x 4 columns]

# %%
train
# Out:
#                    family  sales  onpromotion  dcoilwtico
# date
# 2013-01-01  PERSONAL CARE    0.0            0         NaN
# 2013-01-02  PERSONAL CARE  194.0            0       93.14
# 2013-01-03  PERSONAL CARE  153.0            0       92.97
# 2013-01-04  PERSONAL CARE   88.0            0       93.12
# 2013-01-05  PERSONAL CARE  141.0            0         NaN
# ...                   ...    ...          ...         ...
# 2017-08-11  PERSONAL CARE   53.0            5       48.81
# 2017-08-12  PERSONAL CARE  227.0            7         NaN
# 2017-08-13  PERSONAL CARE   45.0            5         NaN
# 2017-08-14  PERSONAL CARE  159.0            9       47.59
# 2017-08-15  PERSONAL CARE  173.0            9       47.57
#
# [1714 rows x 4 columns]

# %%
Train0 = train0[:-200]
Train1 = train1[:-200]
Train2 = train2[:-200]
Train3 = train3[:-200]
Train4 = train4[:-200]
Train5 = train5[:-200]
Train6 = train6[:-200]
Train7 = train7[:-200]

# %%
Train0
# Out:
#                family   sales  onpromotion  dcoilwtico
# date
# 2013-01-01  GROCERY I     0.0            0       93.14
# 2013-01-02  GROCERY I  2652.0            0       93.14
# 2013-01-03  GROCERY I  2121.0            0       92.97
# 2013-01-04  GROCERY I  2056.0            0       93.12
# 2013-01-05  GROCERY I  2216.0            0       93.20
# ...               ...     ...          ...         ...
# 2017-01-27  GROCERY I  3039.0           31       53.18
# 2017-01-28  GROCERY I  2792.0           29       52.63
# 2017-01-29  GROCERY I  1354.0           23       52.63
# 2017-01-30  GROCERY I  2792.0           27       52.63
# 2017-01-31  GROCERY I  2463.0           32       52.75
#
# [1514 rows x 4 columns]

# %%
Test0 = train0[-200:]
Test1 = train1[-200:]
Test2 = train2[-200:]
Test3 = train3[-200:]
Test4 = train4[-200:]
Test5 = train5[-200:]
Test6 = train6[-200:]

# %%
Test0
# Out:
#                family   sales  onpromotion  dcoilwtico
# date
# 2017-02-01  GROCERY I  3307.0           57       53.90
# 2017-02-02  GROCERY I  2807.0           27       53.55
# 2017-02-03  GROCERY I  3091.0           35       53.81
# 2017-02-04  GROCERY I  3198.0           44       53.01
# 2017-02-05  GROCERY I  1256.0           45       53.01
# ...               ...     ...          ...         ...
# 2017-08-11  GROCERY I  1270.0           24       48.81
# 2017-08-12  GROCERY I  1630.0           28       47.59
# 2017-08-13  GROCERY I   952.0           19       47.59
# 2017-08-14  GROCERY I  2407.0           30       47.59
# 2017-08-15  GROCERY I  2508.0           29       47.57
#
# [200 rows x 4 columns]

# %%
del Train0['family']
del Test0['family']

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
Test0 = scaler.transform(Test0)

# %%
Test0 = pd.DataFrame(Test0)

# %%
#sales, promotion, fuel
Train0.to_csv("gro_train.csv")

# %%
Train0 = scaler.fit_transform(Train0)

# %%
Test0.to_csv("gro_test.csv")

# %% [markdown]
# # 현재는 안 쓰는 원핫인코딩

# %%
#원핫인코딩을 위한 함수 정의
def dummy_data(data, columns):
    for column in columns:
        data = pd.concat([data, pd.get_dummies(data[column], prefix = column)], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
trans_cols = ["store_nbr", "family", "city", "state", "type_x", "cluster", "type_y", "locale", "locale_name", "description",	"transferred"]

# %%
train_trans = dummy_data(train_cp, trans_cols)

# %%
#원핫인코딩 잘 진행됐는지 확인
train_trans
# Out:
#               id        date  ...  transferred_False  transferred_True
# 0              0  2013-01-01  ...                  1                 0
# 1              1  2013-01-01  ...                  1                 0
# 2              2  2013-01-01  ...                  1                 0
# 3              3  2013-01-01  ...                  1                 0
# 4              4  2013-01-01  ...                  1                 0
# ...          ...         ...  ...                ...               ...
# 3054343  3000883  2017-08-15  ...                  1                 0
# 3054344  3000884  2017-08-15  ...                  1                 0
# 3054345  3000885  2017-08-15  ...                  1                 0
# 3054346  3000886  2017-08-15  ...                  1                 0
# 3054347  3000887  2017-08-15  ...                  1                 0
#
# [3054348 rows x 288 columns]

# %%
#원핫인코딩 진행한 csv 파일 저장
train_trans.to_csv("train_trans.csv")

# %%
#표준화
sales_mean = train_trans["sales"].mean(axis=0)
sales_std = train_trans["sales"].std(axis=0)
sales = (train_trans["sales"]-sales_mean) / sales_std
print(sales)
# Out:
# 0         -0.324235
# 1         -0.324235
# 2         -0.324235
# 3         -0.324235
# 4         -0.324235
#              ...
# 3054343    0.071447
# 3054344   -0.184657
# 3054345    1.861044
# 3054346   -0.214959
# 3054347   -0.309785
# Name: sales, Length: 3054348, dtype: float64

# %%
train_trans["std_sales"] = sales

# %%
train_trans
# Out:
#               id        date  ...  transferred_True  std_sales
# 0              0  2013-01-01  ...                 0  -0.324235
# 1              1  2013-01-01  ...                 0  -0.324235
# 2              2  2013-01-01  ...                 0  -0.324235
# 3              3  2013-01-01  ...                 0  -0.324235
# 4              4  2013-01-01  ...                 0  -0.324235
# ...          ...         ...  ...               ...        ...
# 3054343  3000883  2017-08-15  ...                 0   0.071447
# 3054344  3000884  2017-08-15  ...                 0  -0.184657
# 3054345  3000885  2017-08-15  ...                 0   1.861044
# 3054346  3000886  2017-08-15  ...                 0  -0.214959
# 3054347  3000887  2017-08-15  ...                 0  -0.309785
#
# [3054348 rows x 289 columns]

# %%
del train_trans["sales"]

# %%
train_trans
# Out:
#               id        date  ...  transferred_True  std_sales
# 0              0  2013-01-01  ...                 0  -0.324235
# 1              1  2013-01-01  ...                 0  -0.324235
# 2              2  2013-01-01  ...                 0  -0.324235
# 3              3  2013-01-01  ...                 0  -0.324235
# 4              4  2013-01-01  ...                 0  -0.324235
# ...          ...         ...  ...               ...        ...
# 3054343  3000883  2017-08-15  ...                 0   0.071447
# 3054344  3000884  2017-08-15  ...                 0  -0.184657
# 3054345  3000885  2017-08-15  ...                 0   1.861044
# 3054346  3000886  2017-08-15  ...                 0  -0.214959
# 3054347  3000887  2017-08-15  ...                 0  -0.309785
#
# [3054348 rows x 288 columns]

# %%
#categorical class는 one hot encoding으로 바꿔야한다.
#dcoilwtico 는 NULL 값 채워야 함.
train_cp.isnull().sum()
# Out:
# id                   0
# date                 0
# store_nbr            0
# family               0
# sales                0
# onpromotion          0
# city                 0
# state                0
# type_x               0
# cluster              0
# dcoilwtico      955152
# type_y         2551824
# locale         2551824
# locale_name    2551824
# description    2551824
# transferred    2551824
# dtype: int64

# %%
#dcoilwtico의 null값을 뒷값으로 대체(첫행부터 값이 존재하지 않아서 뒷값으로 대체함)
train_trans['dcoilwtico'].fillna(method='bfill', inplace=True)

# %%
train_cp.isnull().sum()
# Out:
# id                   0
# date                 0
# store_nbr            0
# family               0
# sales                0
# onpromotion          0
# city                 0
# state                0
# type_x               0
# cluster              0
# dcoilwtico      955152
# type_y         2551824
# locale         2551824
# locale_name    2551824
# description    2551824
# transferred    2551824
# dtype: int64

# %%
train_trans
# Out:
#               id        date  ...  transferred_True  std_sales
# 0              0  2013-01-01  ...                 0  -0.324235
# 1              1  2013-01-01  ...                 0  -0.324235
# 2              2  2013-01-01  ...                 0  -0.324235
# 3              3  2013-01-01  ...                 0  -0.324235
# 4              4  2013-01-01  ...                 0  -0.324235
# ...          ...         ...  ...               ...        ...
# 3054343  3000883  2017-08-15  ...                 0   0.071447
# 3054344  3000884  2017-08-15  ...                 0  -0.184657
# 3054345  3000885  2017-08-15  ...                 0   1.861044
# 3054346  3000886  2017-08-15  ...                 0  -0.214959
# 3054347  3000887  2017-08-15  ...                 0  -0.309785
#
# [3054348 rows x 288 columns]

# %%
train_trans_I = train_trans.set_index('date')

# %%
del train_trans_I["id"]

# %%
train_trans_I
# Out:
#             onpromotion  dcoilwtico  ...  transferred_True  std_sales
# date                                 ...
# 2013-01-01            0       93.14  ...                 0  -0.324235
# 2013-01-01            0       93.14  ...                 0  -0.324235
# 2013-01-01            0       93.14  ...                 0  -0.324235
# 2013-01-01            0       93.14  ...                 0  -0.324235
# 2013-01-01            0       93.14  ...                 0  -0.324235
# ...                 ...         ...  ...               ...        ...
# 2017-08-15            0       47.57  ...                 0   0.071447
# 2017-08-15            1       47.57  ...                 0  -0.184657
# 2017-08-15          148       47.57  ...                 0   1.861044
# 2017-08-15            8       47.57  ...                 0  -0.214959
# 2017-08-15            0       47.57  ...                 0  -0.309785
#
# [3054348 rows x 286 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
data = train_trans_I.copy()

# %%
del data['std_sales']

# %%
#train data에서 train, test 8:2로 분리
x_train, x_valid, y_train, y_valid = train_test_split(data, train_trans_I['std_sales'], test_size=0.2, shuffle=False)

# %%
x_train
# Out:
#             onpromotion  dcoilwtico  ...  transferred_False  transferred_True
# date                                 ...
# 2013-01-01            0       93.14  ...                  1                 0
# 2013-01-01            0       93.14  ...                  1                 0
# 2013-01-01            0       93.14  ...                  1                 0
# 2013-01-01            0       93.14  ...                  1                 0
# 2013-01-01            0       93.14  ...                  1                 0
# ...                 ...         ...  ...                ...               ...
# 2016-09-12            0       46.28  ...                  0                 0
# 2016-09-12            0       46.28  ...                  0                 0
# 2016-09-12            0       46.28  ...                  0                 0
# 2016-09-12            0       46.28  ...                  0                 0
# ...

# %%
x_valid
# Out:
#             onpromotion  dcoilwtico  ...  transferred_False  transferred_True
# date                                 ...
# 2016-09-12            0       46.28  ...                  0                 0
# 2016-09-12            0       46.28  ...                  0                 0
# 2016-09-12            0       46.28  ...                  0                 0
# 2016-09-12            1       46.28  ...                  0                 0
# 2016-09-12            1       46.28  ...                  0                 0
# ...                 ...         ...  ...                ...               ...
# 2017-08-15            0       47.57  ...                  1                 0
# 2017-08-15            1       47.57  ...                  1                 0
# 2017-08-15          148       47.57  ...                  1                 0
# 2017-08-15            8       47.57  ...                  1                 0
# ...

# %%
#파일 저장
x_train.to_csv("x_train.csv")
x_valid.to_csv("x_valid.csv")
y_train.to_csv("y_train.csv")
y_valid.to_csv("y_valid.csv")
